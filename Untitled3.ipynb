# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman0707006/SD_Aman_0024/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [1,3,9]
l1 = []
for i in l[0:] :
  l1.append(i*i)
print(l1)
# Out:
# [1, 9, 81]

# %%
[i**2 for i in l]
# Out:
# [1, 9, 81]

# %%
d1 = {'s ': "shubham" ,'a ': "aman", 'd' : "deepak"}

# %%
l1 = ["sudh","skills","kumar","data"]
[i.upper() for i in l1]
# Out:
# ['SUDH', 'SKILLS', 'KUMAR', 'DATA']

# %%
d = {"key1" : 1," key2" : 2, "key2" :3}
{k: v**2 for k , v in d.items()}
# Out:
# {'key1': 1, ' key2': 4, 'key2': 9}

# %%
d.items()
# Out:
# dict_items([('key1', 1), (' key2', 2), ('key2', 3)])
