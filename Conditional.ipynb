# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman0707006/SD_Aman_0024/blob/main/Conditional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name = str(input("Enter your name :"))
Course = str(input("Enter your course :"))
Branch = str(input("Enter your branch:"))
Roll = int(input("Enter your roll no :"))
marks = int(input("Enter your marks :"))


print("Name : ",Name[::])
print("Course : ", Course[::])
print("Branch : ", Branch[::])
print("Marks : ", marks)

if marks >= 80:
     print("You will be a part of A0 batch ")
elif marks >= 60 and marks <=80 :
     print("You will be a part of A1 batch")
elif marks >= 40 and marks <=60 :
     print("You will be a part of A1 batch")
else :
     print("You will be a part of A3 batch")
# Out:
# Enter your name :Aman
# Enter your course :B.tech
# Enter your branch:Aiml
# Enter your roll no :0024
# Enter your marks :67
# Name :  Aman
# Course :  B.tech
# Branch :  Aiml
# Marks :  67
# you will be a part of A1 batch

# %%
Roll


Name = str(input("Enter your name :"))
Course = str(input("Enter your course :"))
Branch = str(input("Enter your branch:"))
Roll = int(input("Enter your roll no :"))
Coamarks = int(input("Enter your marks in Coa :"))
Dsmarks = int(input("Enter your marks in Ds :"))
Cymarks = int(input("Enter your marks in Cy :"))


print("Name : ",Name[::])
print("Course : ", Course[::])
print("Branch : ", Branch[::])
print("Marks obtained in Coa : ", Coamarks)
print("Marks obtained in Ds : ", Dsmarks)
print("Marks obtained in Cy : ", Cymarks)

if Coamarks >= 80:
     print("You will be a part of A0 batch ")
elif Coamarks >= 60 and marks <=80 :
     print("You will be a part of A1 batch")
elif Coamarks >= 40 and marks <=60 :
     print("You will be a part of A1 batch")
else :
     print("You will be a part of A3batch")

if  Dsmarks >= 80:
     print("You will be a part of A0 batch ")
elif Dsmarks >= 60 and marks <=80 :
     print("You will be a part of A1 batch")
elif Dsmarks >= 40 and marks <=60 :
     print("You will be a part of A1 batch")
else :
     print("You will be a part of A3 batch")

if Cymarks >= 80:
     print("You will be a part of A0 batch ")
elif Cymarks >= 60 and marks <=80 :
     print("You will be a part of A1 batch")
elif Cymarks >= 40 and marks <=60 :
     print("You will be a part of A1 batch")
else :
     print("You will be a part of A3 batch")
# Out:
# Enter your name :Aman
# Enter your course :B.tech
# Enter your branch:Aim
# Enter your roll no :0024
# Enter your marks in Coa :49
# Enter your marks in Ds :67
# Enter your marks in Cy :88
# Name :  Aman
# Course :  B.tech
# Branch :  Aim
# Marks obtained in Coa :  49
# Marks obtained in Ds :  67
# Marks obtained in Cy :  88
# You will be a part of A3batch
# You will be a part of A1 batch
# You will be a part of A0 batch
