# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman0707006/SD_Aman_0024/blob/main/math%2C_random%2C_datetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  math

# %%
num  = 2
print(math.sqrt(num))
# Out:
# 1.4142135623730951

# %%
print(math.pow(2,5))
# Out:
# 32.0

# %%
print(math.factorial(15))
# Out:
# 1307674368000

# %%
print(math.ceil(4.1))
# Out:
# 5

# %% [markdown]
# floor = nearest lower int
# ceil = nearest upper int

# %%
print(math.floor(5.1))
# Out:
# 5

# %%
print(abs(-40))
# Out:
# 40

# %%
print(math.lcm(12,18))
# Out:
# 36

# %%
print(math.gcd(24,36))
# Out:
# 12

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sin(math.radians(90)))
# Out:
# 1.0

# %%
print(math.tan(math.radians(45)))
# Out:
# 0.9999999999999999

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.log(100))
# Out:
# 4.605170185988092

# %%
import random

# %%
print(random.randint(1,10))
# Out:
# 8

# %%
print(random.randint(1,10))
# Out:
# 9

# %%
print(random.random())
# Out:
# 0.4192714265962929

# %%
print(random.randrange(1,100))
# Out:
# 71

# %%
fruits =["apple","banana","mango","orange"]
print(random.choice(fruits))
# Out:
# banana

# %%
number =[1,2,3,4,5]
random.shuffle(number)
print(number)
# Out:
# [5, 4, 2, 3, 1]

# %%
print(random.uniform(1,10))
# Out:
# 3.9834764894011556

# %%
print(random.choice([True,False]))
# Out:
# False

# %%
otp = random.randint(1000,9999)
print("OTP =" , otp)
# Out:
# OTP = 8199

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2026-07-20 06:26:23.643864

# %%
print(datetime.date.today())
# Out:
# 2026-07-20

# %%
print(datetime.datetime.now().time())
# Out:
# 06:29:56.609947

# %%
print(datetime.datetime.now().year)
# Out:
# 2026

# %%
print(datetime.datetime.now().date())
# Out:
# 2026-07-20

# %%
print(datetime.datetime.now().day)
# Out:
# 20

# %%
print(datetime.datetime.now().second)
# Out:
# 58

# %%
#Custom

d = datetime.date(2026,7,19)

print(d)
# Out:
# 2026-07-19

# %%
t = datetime.time(10,30,45)
print(t)
# Out:
# 10:30:45

# %%
date1 = datetime.date(2006,7,7)
date2 = datetime.date(2026,7,20)

print(date2 - date1)
# Out:
# 7318 days, 0:00:00

# %%
today = datetime.datetime.now()

print(today.strftime("%d-%m-%y"))
# Out:
# 20-07-26

# %%
today = datetime.datetime.now()

print(today.strftime("%H:%M:%S"))
# Out:
# 06:50:03

# %%
today = datetime.datetime.now()

print(today.strftime("%A"))
# Out:
# Monday

# %%
today = datetime.datetime.now()

print(today.strftime("%B"))
# Out:
# July
