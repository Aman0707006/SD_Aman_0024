# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman0707006/SD_Aman_0024/blob/main/Conditional_control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 10
if x > 5:
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
y = 3

if y % 2 == 0:
    print("y is even")
else:
    print("y is odd")
# Out:
# y is odd

# %%
l=[
1,345,45,"sudh",True,5+7j,345,456]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345, 456]

# %%
l[-1:-5:-2]
# Out:
# [456, (5+7j)]

# %%
l[5].real
# Out:
# 5.0

# %%
l[::2]
# Out:
# [1, 45, True, 345]

# %%
s="sucj"

# %%
list(s) + l
# Out:
# ['s', 'u', 'c', 'j', 1, 345, 45, 'sudh', True, (5+7j), 345, 456]

# %%
str(l[4])[:2]
# Out:
# 'Tr'

# %%
L1=[4,6,9]

# %%
l+L1
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345, 456, 4, 6, 9]

# %%
L1*3
# Out:
# [4, 6, 9, 4, 6, 9, 4, 6, 9]

# %%
len(l)
# Out:
# 8

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345, 456]

# %%
l.append(s)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345, 456, 'sucj']

# %%
l.append(L1)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345, 456, 'sucj', [4, 6, 9]]

# %%
l[-1][1]
# Out:
# 6

# %%
l.extend("sudh")

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345,
#  456,
#  'sucj',
#  [4, 6, 9],
#  's',
#  'u',
#  'd',
#  'h',
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend([4,6,9])

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345,
#  456,
#  'sucj',
#  [4, 6, 9],
#  's',
#  'u',
#  'd',
#  'h',
#  's',
#  'u',
#  'd',
#  'h',
#  4,
#  69,
#  4,
#  6,
#  9]

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345,
#  456,
#  'sucj',
#  [4, 6, 9],
#  's',
#  'u',
#  'd',
#  'h',
#  's',
#  'u',
#  'd',
#  'h',
#  4,
#  69,
#  4,
#  6,
#  9]

# %%
L1.insert(1,"sudh")

# %%
L1
# Out:
# [4, 'sudh', 6, 9]

# %%
L1.pop(3)
# Out:
# 9

# %%
L1
# Out:
# [4, 'sudh', 6]

# %%
L1.remove(6)

# %%
L1
# Out:
# [4, 'sudh']

# %%
t=(2,3,4,5,"sudh",45.56,False,45+457j,[3,4,5])

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
type (t)
# Out:
# tuple

# %%
t.append(28)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_641/1533016534.py in <cell line: 0>()
# ----> 1 t.append(28)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.remove(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_641/1350428641.py in <cell line: 0>()
# ----> 1 t.remove(4)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s2={2,4,9,8,8}

# %%
s2
# Out:
# {2, 4, 8, 9}

# %%
s3={1,48,96,45,"sudh",46+57j,(3,5,7)}

# %%
s3
# Out:
# {1, 2, 3}

# %%
s4={1,3,2,2,3,3,1,3,3,1,3,2,2}

# %%
s4
# Out:
# {1, 2, 3}

# %%
l6=[1,3,3,2,3,2,2,3,11,"sudh"]

# %%
l6
# Out:
# [1, 3, 3, 2, 3, 2, 2, 3, 11, 'sudh']

# %%
l6=list(set(l6))

# %%
l6
# Out:
# [1, 2, 3, 11, 'sudh']

# %%
s4={13,4,24,6,2,1,3,1,3,13,}

# %%
s4
# Out:
# {1, 2, 3, 4, 6, 13, 24}

# %%
s4.add(5)

# %%
s4
# Out:
# {1, 2, 3, 4, 5, 6, 13, 24}

# %%
s4.remove(5)

# %%
s4
# Out:
# {1, 2, 3, 4, 6, 13, 24}

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={"key" : "sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2={'name' : " Aman " ," email ": "amankeha03@gmail.com", "number " : "7992084716"}

# %%
d2
# Out:
# {'name': ' Aman ', ' email ': 'amankeha03@gmail.com', 'number ': '7992084716'}

# %%
d3= {234: "sudh " , '_wer' : "Kumar", True: 24234}

# %%
d3
# Out:
# {234: 'sudh ', '_wer': 'Kumar', True: 24234}

# %%
d3['_wer']
# Out:
# 'Kumar'
